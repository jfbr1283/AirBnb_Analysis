# %%
import pandas as pd

df_la_list = pd.read_csv('airbnb_data/la_listings.csv')
df_z_rent = pd.read_csv('airbnb_data/Zip_zori_sm_month.csv')
df_z_sale = pd.read_csv('airbnb_data/Metro_median_sale_price_uc_sfrcondo_sm_month.csv')

# %%
df.head()
# Out:
#                    id                                      listing_url  \
# 0            36978719            https://www.airbnb.com/rooms/36978719
# 1  930487087555321292  https://www.airbnb.com/rooms/930487087555321292
# 2  942342470598573002  https://www.airbnb.com/rooms/942342470598573002
# 3            41240375            https://www.airbnb.com/rooms/41240375
# 4  632034182071149887  https://www.airbnb.com/rooms/632034182071149887
#
#         scrape_id last_scraped           source  \
# 0  20230903194229   2023-09-04  previous scrape
# 1  20230903194229   2023-09-04  previous scrape
# 2  20230903194229   2023-09-04      city scrape
# 3  20230903194229   2023-09-04      city scrape
# 4  20230903194229   2023-09-04      city scrape
#
#                                                 name  \
# 0      Home in Alhambra · 1 bedroom · 1 bed · 1 bath
# 1  Home in La Puente · ★New · 1 bedroom · 1 bed ·...
# 2  Home in Rowland Heights · ★New · 1 bedroom · 2...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44594 entries, 0 to 44593
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            44594 non-null  int64
#  1   listing_url                                   44594 non-null  object
#  2   scrape_id                                     44594 non-null  int64
#  3   last_scraped                                  44594 non-null  object
#  4   source                                        44594 non-null  object
#  5   name                                          44594 non-null  object
#  6   description                                   43937 non-null  object
#  7   neighborhood_overview                         25053 non-null  object
#  8   picture_url                                   44594 non-null  object
# ...

# %%
df['price']
# Out:
# 0         $90.00
# 1         $35.00
# 2         $69.00
# 3        $120.00
# 4        $450.00
#           ...
# 44589    $510.00
# 44590    $168.00
# 44591     $85.00
# 44592    $508.00
# 44593    $480.00
# Name: price, Length: 44594, dtype: object

# %%
df_z_rent.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91982         1       77494        zip        TX    TX      Katy
# 1     91940         3       77449        zip        TX    TX      Katy
# 2     91733         5       77084        zip        TX    TX   Houston
# 3     93144         6       79936        zip        TX    TX   El Paso
# 4     62093         7       11385        zip        NY    NY  New York
#
#                                    Metro        CountyName   2015-01-31  ...  \
# 0   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  1670.679580  ...
# 1   Houston-The Woodlands-Sugar Land, TX     Harris County  1274.676753  ...
# 2   Houston-The Woodlands-Sugar Land, TX     Harris County          NaN  ...
# 3                            El Paso, TX    El Paso County          NaN  ...
# 4  New York-Newark-Jersey City, NY-NJ-PA     Queens County          NaN  ...
#
#     2022-10-31   2022-11-30   2022-12-31   2023-01-31   2023-02-28  \
# ...

# %%
df_z_rent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6884 entries, 0 to 6883
# Columns: 112 entries, RegionID to 2023-07-31
# dtypes: float64(103), int64(3), object(6)
# memory usage: 5.9+ MB

# %%
df_z_rent.loc[[df_z_rent['RegionID'].value_counts()] > 10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-88198ad53ca1> in <module>
# ----> 1 df_z_rent.loc[[df_z_rent['RegionID'].value_counts()] > 10]
#
# TypeError: '>' not supported between instances of 'list' and 'int'
